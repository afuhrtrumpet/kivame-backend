# %%
reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
# %run match_country_to_kiva_loans.py

# %%
loans = KivaAPI().get_loans_by_country('YE')

# %%
KivaAPI().ids_from_loan_dict(loan_dict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-164-6dae485491b2> in <module>()
# ----> 1 KivaAPI().ids_from_loan_dict(loan_dict)
#
# /Users/brianspiering/GitHub/hacksummit/data_sandbox/match_country_to_kiva_loans.py in ids_from_loan_dict(self, loan_dict)
#      18
#      19     def ids_from_loan_dict(self, loan_dict):
# ---> 20          ids = [loan_dict[_]['id'] for _ in loan_dict]
#      21
#      22     def get_loans_by_country(self, country_code):
#
# TypeError: list indices must be integers, not dict

# %%
loan_dict
# Out:
# [{u'activity': u'Home Appliances',
#   u'basket_amount': 0,
#   u'bonus_credit_eligibility': True,
#   u'borrower_count': 4,
#   u'description': {u'languages': [u'en']},
#   u'funded_amount': 0,
#   u'id': 722787,
#   u'image': {u'id': 1623051, u'template_id': 1},
#   u'lender_count': 0,
#   u'loan_amount': 1025,
#   u'location': {u'country': u'Yemen',
#    u'country_code': u'YE',
#    u'geo': {u'level': u'country', u'pairs': u'15.5 47.5', u'type': u'point'},
#    u'town': u'Taiz'},
#   u'name': u'Al- Mas 26 Group',
#   u'partner_id': 205,
#   u'planned_expiration_date': u'2014-07-15T00:40:03Z',
#   u'posted_date': u'2014-06-15T00:40:03Z',
#   u'sector': u'Personal Use',
#   u'status': u'fundraising',
#   u'theme': u'Islamic Finance',
#   u'use': u'to purchase home appliances for her own house.'},
#  {u'activity': u'Clothing Sales',
#   u'basket_amount': 0,
#   u'bonus_credit_eligibility': False,
#   u'borrower_count': 1,
#   u'description': {u'languages': [u'en']},
# ...
